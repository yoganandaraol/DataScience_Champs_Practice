# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="110" /></center>
#
# # PCA - Assignment

# %% [markdown]
# ## Breast Cancer Wisconsin

# %% [markdown]
# - The dataset consist of features which are computed from a digitized image of a **fine needle aspirate** (FNA) of a **breast mass**.
#
# - They describe characteristics of the **cell nuclei** present in the image.
#
# - Dataset can also be found on the UCI Machine Learning Repository:
#
#   - https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
#
# - Attribute Information:
#
#   - **ID** number
#
#   - **Diagnosis** (M = malignant, B = benign)
#
# <br>

# %% [markdown]
# - Ten real-valued features are computed for each cell nucleus:
#
# | **Column Name** | **Description** |
# |:---------------:|:---------------:|
# | **radius** | Mean of distances from center to points on the perimeter. |
# | **texture** | Standard deviation of gray-scale values. |
# | **perimeter** | Perimeter value. |
# | **area** | Area values. |
# | **smoothness** | Local variation in radius lengths. |
# | **compactness** | perimeter^2 / area - 1.0 |
# | **concavity** | Severity of concave portions of the contour. |
# | **concave points** | Number of concave portions of the contour |
# | **symmetry** | Symmetry value. |
# | **fractal dimension** | Coastline approximation - 1 |
#
#
# <br>

# %% [markdown]
# - As you can see we have **10 base column** names mentioned above.
#
# - The **mean**, **standard error** and **worst** (mean of the three largest values) of these features were computed for each image.
#
# - It resulted in $10 * 3 = 30$ features.
#
# - For instance:
#
#   - Field 3 is `radius_mean`
#
#   - Field 13 is `radius_se`
#
#   - Field 23 is `radius_worst`
#
# - All feature values are recoded with **four significant** digits.
#
# - Missing attribute values: **none**
#
# - Class distribution: **357 benign**, **212 malignant**

# %% [markdown]
# ### Import the dataset

# %%
import pandas as pd

# %%
cancer = pd.read_csv('data.csv')
cancer.head()

# %% [markdown]
# #### Check the shape of the dataset

# %%
cancer.shape

# %% [markdown]
# #### Check the columns present in the dataset

# %%
cancer.columns

# %% [markdown]
# #### Count of 0 and 1 from the cancer variable.

# %%
cancer.diagnosis.value_counts()

# %% [markdown]
# #### Check the info of the dataset

# %%
cancer.info()

# %% [markdown]
# #### Check the descriptive statisticss of the dataset

# %%
cancer.describe()

# %% [markdown]
# ### Q 1. Write code to check the missing values present in the dataset.

# %%
def me():
    return # your code to know if there is any missing value or not
me()

# %% [markdown]
# ### Q 2. Write code to delete the column having mostly missing values present in the dataset.

# %%
def generate():
    # your code here
    return 
generate()

# %% [markdown]
# ### Q 3. Convert the categorical variable `diagnosis` to binary (0 and 1 values) using the map function.

# %%
def generate():
    return #your code here
cancer['diagnosis'] = generate()

# %% [markdown]
# ### Q 4. Extract the independent variables to create a dataframe X.

# %%
X = pd.DataFrame()
def generate():
    # write your code to create a dataframe of dependent variables excluding 'diagnosis' variable
    return X
X = generate()

# %% [markdown]
# ### Q 5. Extract the dependent variable into a dataframe 'y' for model prediction.

# %%
y = pd.DataFrame()
def generate():
    # write your code to create a dataframe which consists only of dependepent variable
    return y
y = generate()

# %% [markdown]
# ### Q 6. Split X and y into train and test dataset.
#
# - Use `test_size` of **0.25**
#
# - Use `random_state` equal to **1**.

# %%
from sklearn.model_selection import train_test_split
def generate():
    return # train test split using train_test_split of 75:25 and random state=1
X_train, X_test, y_train, y_test = generate()

# %% [markdown]
# ### 6.2 Check the shape of X and y of train dataset

# %%
def generate():
    # your code here
    return 
generate()

# %% [markdown]
# ### 6.2 Check the shape of X and y of test dataset

# %%
def generate():
    # your code here
    return 
generate()

# %% [markdown]
# ### Q 7. Instantiate RandomForestClassifier using scikit learn
#
# - Use `random_state` equal to **0**.

# %%
from sklearn.ensemble import RandomForestClassifier
def generate():
    # instantiate RandomForestClassifer to new variable rfc
    return rfc
rfc = generate()

# %% [markdown]
# ### Q 8. Use RandomizedSearchCV  for hyperparameter tuning of your random forest classifier.
#
# - Keep `n_iter` as **50** and `random_state` as **0** for the RandomizedSearchCV.
#
# - For the parameter grid use the below values:
#
#     - `max_depth`: **range(2, 5)**
#
#     - `min_samples_split`: **sp_randint(2, 11)**
#
#     - `min_samples_leaf`: **sp_randint(1, 11)**
#
#     - `n_estimators`: **[100, 400, 700, 1000, 1500]**
#
#     - `max_features`: **['sqrt', 'log2', None]**

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint

def generate():
    # your code here
    return # variable for RandomizedSearchCV model
rfc = generate()

# %% [markdown]
# ### Q 9. Fit the model on X_train and y_train also print the time taken by the classifier.

# %%
import time
def generate():
    # code to fit the model 
    # print time taken
    return # time taken
generate()

# %% [markdown]
# ### Q 10. Use the model for making predictions on X_test.

# %%
predictions = pd.DataFrame()
def generate():
    # create the model prediction on X_test data using the above created dataframe
    return predictions
predictions = generate()

# %% [markdown]
# ### Q 11. Perform model evaluation on the test set using accuracy score.

# %%
from sklearn.metrics import accuracy_score
def generate():
    # compute and print the accuracy score
    return 
generate()

# %% [markdown]
# ### Q 12. Use StandardScaler to normalize X
#
# - **Fit** the scaler on **X**.
#
# - **Return** the transform of **X** obtained using `.transform(X)` on the **scaler**.

# %%
from sklearn.preprocessing import StandardScaler
def generate():
    # Your code here
    return #standardized X
X = generate()

# %% [markdown]
# ### Q 13.  Apply PCA to fit X and plot the variation of % of Variance Explained with Number of Features.
#
# - Apply the PCA model with all the principal components.
#
# - Use `random_state` as **0** in the PCA model.
#
# - Look at the plot and try to figure out the value of **number of principal components** explaining **95%** of variance.

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
def generate():

    # your code here
    return # variable to plot graph
generate()

# %% [markdown]
# ### Q 14. Applying PCA with number of principal components = 11.
#
# - Use `random_state` as **0** in the PCA model.

# %%
from sklearn.decomposition import PCA
def generate():
    # your code here
    return # variable for X after applying PCA
X = generate()
print(X.shape)

# %% [markdown]
# ### Q 15. Split X and y into train and test dataset.
#
# - Use `test_size` of **0.25**
#
# - Use `random_state` equal to **1**.

# %%
from sklearn.model_selection import train_test_split
def generate():
    return # train test split using train_test_split of 75:25 and random state=0
X_train, X_test, y_train, y_test = generate()

# %%
print(X_train.shape,X_test.shape)

# %% [markdown]
# ### Q 16. Fit the rfc model on X_train and y_train also print the time taken by the classifier.

# %%
import time
def generate():
     # code to fit the model 
     # print time taken
    return # time taken
generate()

# %% [markdown]
# ### Q 17. Use the model for making predictions on X_test.

# %%
predictions = pd.DataFrame()
def generate():
    # create the model prediction on X_test data using the above created dataframe
    return # your varaible for predicted values
predictions_pca = generate()

# %% [markdown]
# ### Q 18. Perform model evaluation on the test set using accuracy score.

# %%
from sklearn.metrics import accuracy_score
def generate():
    # compute and print the accuracy score
    return 
generate()

# %% [markdown]
# ### Q 19. Find the difference between the time taken by both the models.

# %%
def generate():
    return # your variable
difference = generate()
